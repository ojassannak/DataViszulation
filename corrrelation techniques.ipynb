# %%
# threshold = 0.8

# # Remove rows where any correlation value is greater than the threshold
# filtered_df = df.loc[~(df > threshold).any(axis=1)]

# %% [markdown]
# <h4>Test</h4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.array([4,11,15,21,28,34,39,35,47,55])
y=np.array([10,22,31,36,48,51,58,61,69,77])
z=np.array([92,83,89,56,61,56,48,41,26,19])
p=np.array([56,44,27,65,38,61,23,75,36,58])

# %%
df=pd.DataFrame({
    'X':x,
    'Y':y,
    'Z':z,
    'P':p
})

# %%
df
# Out:
#     X   Y   Z   P
# 0   4  10  92  56
# 1  11  22  83  44
# 2  15  31  89  27
# 3  21  36  56  65
# 4  28  48  61  38
# 5  34  51  56  61
# 6  39  58  48  23
# 7  35  61  41  75
# 8  47  69  26  36
# 9  55  77  19  58

# %%
np.corrcoef(x,y)
# Out:
# array([[1.  , 0.99],
#        [0.99, 1.  ]])

# %%
np.corrcoef(x,z)
# Out:
# array([[ 1.       , -0.9598548],
#        [-0.9598548,  1.       ]])

# %%
np.corrcoef(y,z)
# Out:
# array([[ 1.        , -0.95264583],
#        [-0.95264583,  1.        ]])

# %%
df.corr()
# Out:
#           X         Y         Z         P
# X  1.000000  0.988286 -0.959855  0.024336
# Y  0.988286  1.000000 -0.952646  0.041168
# Z -0.959855 -0.952646  1.000000 -0.200311
# P  0.024336  0.041168 -0.200311  1.000000

# %%
#
df=pd.read_csv('C:/Users/duasp/students/datasets/mtcars.csv')

# %%
df.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
df.shape
# Out:
# (32, 11)

# %%
x=df.drop('mpg',axis=1)

# %%
x
# Out:
#     cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0     6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1     6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2     4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4     8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5     6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6     8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7     4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8     4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9     6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# ...

# %%
correlation_matrix=x.corr()
correlated_features=set()

# %%
# %precision 2
for i in range(len(correlation_matrix)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i,j]>0.8):
            correlated_features.add(correlation_matrix.columns[i])

# %%
df.drop(correlated_features,axis=1,inplace=True)

# %%
df.corr()
# Out:
#            mpg       cyl      drat      qsec        vs        am      gear  \
# mpg   1.000000 -0.852162  0.681172  0.418684  0.664039  0.599832  0.480285
# cyl  -0.852162  1.000000 -0.699938 -0.591242 -0.810812 -0.522607 -0.492687
# drat  0.681172 -0.699938  1.000000  0.091205  0.440278  0.712711  0.699610
# qsec  0.418684 -0.591242  0.091205  1.000000  0.744535 -0.229861 -0.212682
# vs    0.664039 -0.810812  0.440278  0.744535  1.000000  0.168345  0.206023
# am    0.599832 -0.522607  0.712711 -0.229861  0.168345  1.000000  0.794059
# gear  0.480285 -0.492687  0.699610 -0.212682  0.206023  0.794059  1.000000
# carb -0.550925  0.526988 -0.090790 -0.656249 -0.569607  0.057534  0.274073
#
#           carb
# mpg  -0.550925
# cyl   0.526988
# drat -0.090790
# qsec -0.656249
# vs   -0.569607
# am    0.057534
# gear  0.274073
# carb  1.000000

# %% [markdown]
# <h4>correlation width</h4>

# %%
#
df=pd.read_csv('C:/Users/duasp/students/datasets/mtcars.csv')

# %%
df.corrwith(df['mpg'])
# Out:
# mpg     1.000000
# cyl    -0.852162
# disp   -0.847551
# hp     -0.776168
# drat    0.681172
# wt     -0.867659
# qsec    0.418684
# vs      0.664039
# am      0.599832
# gear    0.480285
# carb   -0.550925
# dtype: float64

# %% [markdown]
# <h4>Rank Correlation</h4>

# %%
from scipy.stats import rankdata

# %%
# Out:
#     cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0     6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1     6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2     4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4     8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5     6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6     8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7     4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8     4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9     6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# ...

# %%
x= np.array([4,11,15,21,28,34,39,35,47,55])
y=np.array([10,22,31,36,48,51,58,61,69,77])
z=np.array([92,83,89,56,61,56,48,41,26,19])
p=np.array([56,44,27,65,38,61,23,75,36,58])

# %%
df=pd.DataFrame({
    'X':x,
    'Y':y,
    'Z':z,
    'P':p
})

# %%
x
# Out:
# array([ 4, 11, 15, 21, 28, 34, 39, 35, 47, 55])

# %%
rx1=rankdata(x)

# %%
ry1=rankdata(y)

# %%
rz1=rankdata(z)

# %%
rp1=rankdata(p)

# %% [markdown]
# <h4>Spearman's Correlation</h4>

# %% [markdown]
# #same as pearson but rank is taken instead of value

# %%
from scipy.stats import spearmanr,pearsonr

# %%
#formmula u can use or use the function
num=len(rx1)*(np.sum(rx1*ry1))-(np.sum(rx1) * np.sum(ry1))
den=np.sqrt((len(rx1)*np.sum(rx1**2)-(np.sum(rx1)**2))*((len(ry1)*np.sum(ry1**2)-(np.sum(ry1)**2))))

# %%
spearmanr(rx1,ry1)
# Out:
# SignificanceResult(statistic=0.9878787878787878, pvalue=9.307459988955517e-08)

# %%
pearsonr(rankdata(x),rankdata(y))
# Out:
# PearsonRResult(statistic=0.9878787878787879, pvalue=9.307459988955525e-08)

# %%
df.corr(method='spearman')
# Out:
#           X         Y         Z         P
# X  1.000000  0.987879 -0.954412 -0.018182
# Y  0.987879  1.000000 -0.966570  0.090909
# Z -0.954412 -0.966570  1.000000 -0.194530
# P -0.018182  0.090909 -0.194530  1.000000

# %%
a=np.array([12,15,27,48,56,79])
b=np.array([10,23,33,37,56,89])

# %%
spearmanr(a,b)
# Out:
# SignificanceResult(statistic=1.0, pvalue=0.0)

# %%
pearsonr(a,b)
# Out:
# PearsonRResult(statistic=0.9603401398228046, pvalue=0.0023281661774570725)

# %% [markdown]
# <h4>Kendall's Correlation Coefficient: THE TAU</h4>

# %%
from scipy.stats import kendalltau

# Sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 6, 7, 8, 7])

# Calculate Kendall's tau
kendalltau(x, y)
# Out:
# SignificanceResult(statistic=0.7378647873726218, pvalue=0.07697417298126674)

# %%
df.corr(method='kendall')
# Out:
#           X         Y         Z         P
# X  1.000000  0.955556 -0.853986 -0.022222
# Y  0.955556  1.000000 -0.898933  0.022222
# Z -0.853986 -0.898933  1.000000 -0.134840
# P -0.022222  0.022222 -0.134840  1.000000

# %%
kendalltau(a,b)
# Out:
# SignificanceResult(statistic=0.9999999999999999, pvalue=0.002777777777777778)
