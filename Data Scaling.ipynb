# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h4>Standardization</h4>

# %% [markdown]
# <h5>Dataset:  social network ads.csv</h5>

# %%
cd students/
# Out:
# C:\Users\duasp\students

# %%
df=pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
x=df[['Age','EstimatedSalary']]

# %%
x.describe()
# Out:
#               Age  EstimatedSalary
# count  400.000000       400.000000
# mean    37.655000     69742.500000
# std     10.482877     34096.960282
# min     18.000000     15000.000000
# 25%     29.750000     43000.000000
# 50%     37.000000     70000.000000
# 75%     46.000000     88000.000000
# max     60.000000    150000.000000

# %%
plt.scatter(df['Age'],df['EstimatedSalary'], c=df['Purchased'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_std=scaler.fit_transform(x)

# %%
x_std
# Out:
# array([[-1.78179743, -1.49004624],
#        [-0.25358736, -1.46068138],
#        [-1.11320552, -0.78528968],
#        [-1.01769239, -0.37418169],
#        [-1.78179743,  0.18375059],
#        [-1.01769239, -0.34481683],
#        [-1.01769239,  0.41866944],
#        [-0.54012675,  2.35674998],
#        [-1.20871865, -1.07893824],
#        [-0.25358736, -0.13926283],
#        [-1.11320552,  0.30121002],
#        [-1.11320552, -0.52100597],
#        [-1.6862843 ,  0.47739916],
#        [-0.54012675, -1.51941109],
#        [-1.87731056,  0.35993973],
#        [-0.82666613,  0.30121002],
#        [ 0.89257019, -1.3138571 ],
#        [ 0.70154394, -1.28449224],
#        [ 0.79705706, -1.22576253],
#        [ 0.98808332, -1.19639767],
#        [ 0.70154394, -1.40195167],
#        [ 0.89257019, -0.60910054],
#        [ 0.98808332, -0.84401939],
#        [ 0.70154394, -1.40195167],
#        [ 0.79705706, -1.37258681],
#        [ 0.89257019, -1.46068138],
#        [ 1.08359645, -1.22576253],
# ...

# %%
x_std=pd.DataFrame(x_std, columns=x.columns)

# %%
x_std
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
x_std.describe()
# Out:
#                 Age  EstimatedSalary
# count  4.000000e+02     4.000000e+02
# mean  -7.105427e-17    -1.776357e-17
# std    1.001252e+00     1.001252e+00
# min   -1.877311e+00    -1.607506e+00
# 25%   -7.550313e-01    -7.852897e-01
# 50%   -6.256110e-02     7.561451e-03
# 75%    7.970571e-01     5.361289e-01
# max    2.134241e+00     2.356750e+00

# %%
plt.subplot(1,2,1)
plt.title('Original Data')
plt.scatter(df['Age'],df['EstimatedSalary'], c=df['Purchased'])

plt.subplot(1,2,2)
plt.title('standardized Data')
plt.scatter(x_std['Age'],x_std['EstimatedSalary'], c=df['Purchased'])

# %% [markdown]
# <h4>Normalization</h4>

# %%
https://media.licdn.com/dms/image/C4E12AQFwgCS444bQUA/article-cover_image-shrink_600_2000/0/1622199152107?e=2147483647&v=beta&t=T7qU2W4a2C25rcVeMUbCdPrb8qX7k2kDTRAmHGcssFQ

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_norm=scaler.fit_transform(x)

# %%
x_norm
# Out:
# array([[0.02380952, 0.02962963],
#        [0.4047619 , 0.03703704],
#        [0.19047619, 0.20740741],
#        [0.21428571, 0.31111111],
#        [0.02380952, 0.45185185],
#        [0.21428571, 0.31851852],
#        [0.21428571, 0.51111111],
#        [0.33333333, 1.        ],
#        [0.16666667, 0.13333333],
#        [0.4047619 , 0.37037037],
#        [0.19047619, 0.48148148],
#        [0.19047619, 0.27407407],
#        [0.04761905, 0.52592593],
#        [0.33333333, 0.02222222],
#        [0.        , 0.4962963 ],
#        [0.26190476, 0.48148148],
#        [0.69047619, 0.07407407],
#        [0.64285714, 0.08148148],
#        [0.66666667, 0.0962963 ],
#        [0.71428571, 0.1037037 ],
#        [0.64285714, 0.05185185],
#        [0.69047619, 0.25185185],
#        [0.71428571, 0.19259259],
#        [0.64285714, 0.05185185],
#        [0.66666667, 0.05925926],
#        [0.69047619, 0.03703704],
#        [0.73809524, 0.0962963 ],
#        [0.69047619, 0.11111111],
# ...

# %%
x.min()
# Out:
# Age                   18.0
# EstimatedSalary    15000.0
# dtype: float64

# %%
x_norm=pd.DataFrame(x_norm, columns=x.columns)

# %%
x_norm
# Out:
#           Age  EstimatedSalary
# 0    0.023810         0.029630
# 1    0.404762         0.037037
# 2    0.190476         0.207407
# 3    0.214286         0.311111
# 4    0.023810         0.451852
# ..        ...              ...
# 395  0.666667         0.192593
# 396  0.785714         0.059259
# 397  0.761905         0.037037
# 398  0.428571         0.133333
# 399  0.738095         0.155556
#
# [400 rows x 2 columns]

# %%
x_norm.describe()
# Out:
#               Age  EstimatedSalary
# count  400.000000       400.000000
# mean     0.467976         0.405500
# std      0.249592         0.252570
# min      0.000000         0.000000
# 25%      0.279762         0.207407
# 50%      0.452381         0.407407
# 75%      0.666667         0.540741
# max      1.000000         1.000000

# %%
plt.subplot(1,2,1)
plt.title('Original Data')
plt.scatter(df['Age'],df['EstimatedSalary'], c=df['Purchased'])

plt.subplot(1,2,2)
plt.title('Normalizaion Data')
plt.scatter(x_norm['Age'],x_norm['EstimatedSalary'], c=df['Purchased'])
